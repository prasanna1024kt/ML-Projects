# %%
import pandas as pd
import pyarrow
import numpy as np

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/Customer_fraud_detection/notebook
# ['EDA.ipynb', 'convert_csv_to_parquet.ipynb', '.ipynb_checkpoints']

# %%
import sys
import sys
# !python3 -m pip install --upgrade pip
# !python3 -m pip install matplotlib
# Out:
# Requirement already satisfied: pip in /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/venv/lib/python3.13/site-packages (25.0)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.0 MB/s eta 0:00:002 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.0
#     Uninstalling pip-25.0:
#       Successfully uninstalled pip-25.0
# Successfully installed pip-25.3
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-macosx_10_13_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-macosx_10_13_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/venv/lib/python3.13/site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.0.0-cp313-cp313-macosx_10_13_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/prasanna/Desktop/DataTalksClubs/ml-projects-work/venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp313-cp313-macosx_10_13_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 5.6 MB/s  0:00:015.4 MB/s eta 0:00:01:06
# Downloading contourpy-1.3.3-cp313-cp313-macosx_10_13_x86_64.whl (293 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp313-cp313-macosx_10_13_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.9 MB/s  0:00:00m 10.4 MB/s eta 0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-macosx_10_13_x86_64.whl (66 kB)
# Downloading pillow-12.0.0-cp313-cp313-macosx_10_13_x86_64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 8.7 MB/s  0:00:00m 9.0 MB/s eta 0:00:01
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib] 6/7 [matplotlib]ourpy]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 kiwisolver-1.4.9 matplotlib-3.10.8 pillow-12.0.0 pyparsing-3.3.1

# %%
parquet_test_identity = '../datasets/test_identity.parquet'
parquet_train_identity = '../datasets/train_identity.parquet'
parquet_test_trans = '../datasets/test_transaction.parquet'
parquet_train_trans = '../datasets/train_transaction.parquet'

# %%
import sys
print(sys.executable)
# Out:
# /usr/local/Cellar/jupyterlab/4.3.5/libexec/bin/python

# %% [markdown]
# ## Load transaction and identity datasets

# %%
df_trans = pd.read_parquet("../datasets/train_transaction.parquet")
df_trans.shape
# Out:
# (590540, 394)

# %%
df_ident = pd.read_parquet("../datasets/train_identity.parquet")
df_ident.shape
# Out:
# (144233, 1)

# %% [markdown]
# ## Fraud target distribution

# %%
df_trans["isFraud"].value_counts(normalize=True) * 100
# Out:
# isFraud
# 0    96.500999
# 1     3.499001
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
vc = df_trans["isFraud"].value_counts()
plt.bar(vc.index, vc.values)
plt.title("Fraud vs Non-Fraud")
plt.xticks([0,1], ["Non-Fraud", "Fraud"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 vc = df_trans["isFraud"].value_counts()
#       3 plt.bar(vc.index, vc.values)
#
# ModuleNotFoundError: No module named 'matplotlib'
